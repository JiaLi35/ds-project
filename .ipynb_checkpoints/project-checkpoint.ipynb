# %%
# Data manipulation and visualization
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
import warnings
warnings.filterwarnings('ignore')

# Deep Learning libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, Input, Conv2D, MaxPooling2D,Flatten
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications import VGG16, ResNet50, MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# Scikit-learn for metrics
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.metrics import ConfusionMatrixDisplay

# %%
patient_df = pd.read_csv('./skin-cancer-mnist-ham10000/HAM10000_metadata.csv')

# %% [markdown]
# ## Checking the Data & Cleaning

# %%
patient_df
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
patient_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10015 entries, 0 to 10014
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   lesion_id     10015 non-null  object
#  1   image_id      10015 non-null  object
#  2   dx            10015 non-null  object
#  3   dx_type       10015 non-null  object
#  4   age           9958 non-null   float64
#  5   sex           10015 non-null  object
#  6   localization  10015 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 547.8+ KB

# %%
patient_df.describe()
# Out:
#                age
# count  9958.000000
# mean     51.863828
# std      16.968614
# min       0.000000
# 25%      40.000000
# 50%      50.000000
# 75%      65.000000
# max      85.000000

# %%
patient_df.isna().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# dtype: int64

# %%
patient_df.duplicated().sum()
# Out:
# 0

# %%
patient_df['age'] = patient_df['age'].fillna(patient_df['age'].mean())

# %%
patient_df.isna().sum()
# Out:
# lesion_id       0
# image_id        0
# dx              0
# dx_type         0
# age             0
# sex             0
# localization    0
# dtype: int64

# %%
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %%
patient_df['cell_type'] = patient_df['dx'].map(lesion_type_dict)
patient_df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                         cell_type
# 0  Benign keratosis-like lesions
# 1  Benign keratosis-like lesions
# 2  Benign keratosis-like lesions
# 3  Benign keratosis-like lesions
# 4  Benign keratosis-like lesions

# %%
patient_df['age'].value_counts()
# Out:
# age
# 45.000000    1299
# 50.000000    1187
# 55.000000    1009
# 40.000000     985
# 60.000000     803
# 70.000000     756
# 35.000000     753
# 65.000000     731
# 75.000000     618
# 30.000000     464
# 80.000000     404
# 85.000000     290
# 25.000000     247
# 20.000000     169
# 5.000000       86
# 15.000000      77
# 51.863828      57
# 10.000000      41
# 0.000000       39
# Name: count, dtype: int64

# %%
patient_df = patient_df[patient_df['age']!=0]

# %%
patient_df['sex'].value_counts()
# Out:
# sex
# male       5383
# female     4538
# unknown      55
# Name: count, dtype: int64

# %%
patient_df = patient_df[patient_df['sex']!='unknown']

# %%
patient_df['age'].value_counts()
# Out:
# age
# 45.000000    1297
# 50.000000    1187
# 55.000000    1009
# 40.000000     985
# 60.000000     800
# 70.000000     756
# 35.000000     750
# 65.000000     731
# 75.000000     618
# 30.000000     464
# 80.000000     404
# 85.000000     290
# 25.000000     247
# 20.000000     169
# 5.000000       86
# 15.000000      77
# 10.000000      41
# 51.863828      10
# Name: count, dtype: int64

# %%
patient_df['sex'].value_counts()
# Out:
# sex
# male      5383
# female    4538
# Name: count, dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=patient_df, x='cell_type')
plt.xticks(rotation=45,ha='right')
plt.title('Skin Cell Type Distribution')
plt.xlabel('Skin Cell Type')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=patient_df, x='dx_type')
plt.xticks(rotation=45,ha='right')
plt.title('Confirmation Examination Type Distribution')
plt.xlabel('Confirmation Examination Type')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=patient_df, x='localization')
plt.xticks(rotation=45,ha='right')
plt.title('Localization of Skin Lesion Distribution')
plt.xlabel('Localization of Skin Lesion')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(x=patient_df['age'], bins=30, edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age of Patients')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=patient_df, x='sex')
plt.xticks(rotation=45,ha='right')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=patient_df, x='cell_type', hue='sex')
plt.xticks(rotation=45,ha='right')
plt.title('Skin Cell Type Distribution')
plt.xlabel('Skin Cell Type')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=patient_df, x='age', hue='sex')
plt.xticks(rotation=45,ha='right')
plt.title('Skin Cell Type Distribution')
plt.xlabel('Skin Cell Type')
plt.ylabel('')
plt.show()

# %%
patient_df['image_path'] = patient_df['image_id'].astype(str) + '.jpg'

# %%
BASE_DIR = Path('./skin-cancer-mnist-ham10000')  # Update this to your data directory
TRAIN_DIR = BASE_DIR / 'train'
TEST_DIR = BASE_DIR / 'test'
SAMPLE_DIR = BASE_DIR / 'sample'

# Image parameters
IMG_HEIGHT = 224
IMG_WIDTH = 224
IMG_CHANNELS = 3
BATCH_SIZE = 32
TARGET_SIZE = (IMG_HEIGHT, IMG_WIDTH)

print(f"{TRAIN_DIR}\nTrain directory exists: {TRAIN_DIR.exists()}")
print(f"{TEST_DIR}\nTest directory exists: {TEST_DIR.exists()}")
print(f"{SAMPLE_DIR}\nSample directory exists: {SAMPLE_DIR.exists()}")
# Out:
# skin-cancer-mnist-ham10000\train
# Train directory exists: True
# skin-cancer-mnist-ham10000\test
# Test directory exists: True
# skin-cancer-mnist-ham10000\sample
# Sample directory exists: True

# %%
# Count images in each set
def count_images(directory):
    return len(list(directory.glob('*.jpg')))
    
# Count images in each set
train_total = count_images(TRAIN_DIR)
test_total = count_images(TEST_DIR)

print(f"Training images: {train_total}")
print(f"Test images: {test_total}")
# Out:
# Training images: 8000
# Test images: 2015

# %%
def plot_sample_images(directory, num_samples=12, figsize=(10, 6)):
    fig, axes = plt.subplots(2, 3, figsize=figsize)
    axes = axes.ravel()
    images = list(directory.glob('*.jpg'))

    for idx in range(0,6):
        if images:
            random_image = np.random.choice(images)
            img = load_img(random_image, target_size=(IMG_HEIGHT, IMG_WIDTH))

            axes[idx].imshow(img)
            axes[idx].set_title(random_image.stem, fontsize=10)
            axes[idx].axis('off')
    
    plt.tight_layout()
    plt.suptitle('Sample Skin Cancer Images', fontsize=16, y=1.02)
    plt.show()

plot_sample_images(TRAIN_DIR)

# %% [markdown]
# ## Training the Model

# %%
train_data = ImageDataGenerator(
    rescale=1./255, # normalize pixels values to 0-1
    rotation_range=40, # rotating images up 40degress 
    width_shift_range=0.2, # randomly shiftting horizontally by 20%
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

# %%
test_data = ImageDataGenerator(
    rescale=1./255
)

# %%
train_gen = train_data.flow_from_dataframe(
    dataframe=patient_df,
    directory=TRAIN_DIR,
    x_col='image_path',
    y_col='cell_type',  
    target_size=TARGET_SIZE,
    class_mode='sparse',
    batch_size=BATCH_SIZE
)

test_gen = test_data.flow_from_dataframe(
    dataframe=patient_df,
    directory=TEST_DIR,
    x_col='image_path',
    y_col='cell_type',
    target_size=TARGET_SIZE,
    class_mode='sparse',
    batch_size=BATCH_SIZE
)
# Out:
# Found 7929 validated image filenames belonging to 7 classes.
# Found 1992 validated image filenames belonging to 7 classes.

# %%
test_gen.class_indices
# Out:
# {'Actinic keratoses': 0,
#  'Basal cell carcinoma': 1,
#  'Benign keratosis-like lesions ': 2,
#  'Dermatofibroma': 3,
#  'Melanocytic nevi': 4,
#  'Melanoma': 5,
#  'Vascular lesions': 6}

# %%
resnet_model = ResNet50(
    weights = 'imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

resnet_model.trainable=False

# %%
model1 = Sequential([
    resnet_model,
    GlobalAveragePooling2D(),
    Dense(512,activation='relu'),
    Dropout(0.2),
    Dense(512,activation='relu'),
    Dropout(0.2),
    Dense(units=7,activation='softmax')
])

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 7, 7, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,903,047 (95.00 MB)
#  Trainable params: 1,315,335 (5.02 MB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
model1.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=10, 
    restore_best_weights=True
)

# %%
history1 = model1.fit(
    train_gen,
    validation_data=test_gen,
    epochs=20,
    callbacks=[early_stopping]
    # class_weight=class_weights
)
# Out:
# Epoch 1/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 455s 2s/step - accuracy: 0.6679 - loss: 1.1804 - val_accuracy: 0.6581 - val_loss: 1.1361
# Epoch 2/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 379s 2s/step - accuracy: 0.6708 - loss: 1.1525 - val_accuracy: 0.6581 - val_loss: 1.1339
# Epoch 3/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 395s 2s/step - accuracy: 0.6708 - loss: 1.1413 - val_accuracy: 0.6581 - val_loss: 1.1305
# Epoch 4/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 394s 2s/step - accuracy: 0.6708 - loss: 1.1297 - val_accuracy: 0.6581 - val_loss: 1.1103
# Epoch 5/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 388s 2s/step - accuracy: 0.6708 - loss: 1.1356 - val_accuracy: 0.6581 - val_loss: 1.1195
# Epoch 6/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 387s 2s/step - accuracy: 0.6708 - loss: 1.1264 - val_accuracy: 0.6581 - val_loss: 1.1228
# Epoch 7/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 395s 2s/step - accuracy: 0.6708 - loss: 1.1101 - val_accuracy: 0.6581 - val_loss: 1.0878
# Epoch 8/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 390s 2s/step - accuracy: 0.6708 - loss: 1.1070 - val_accuracy: 0.6581 - val_loss: 1.0948
# Epoch 9/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 390s 2s/step - accuracy: 0.6708 - loss: 1.1098 - val_accuracy: 0.6581 - val_loss: 1.1462
# Epoch 10/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 391s 2s/step - accuracy: 0.6708 - loss: 1.0976 - val_accuracy: 0.6581 - val_loss: 1.1127
# Epoch 11/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 390s 2s/step - accuracy: 0.6708 - loss: 1.1222 - val_accuracy: 0.6581 - val_loss: 1.1394
# Epoch 12/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 405s 2s/step - accuracy: 0.6708 - loss: 1.1357 - val_accuracy: 0.6581 - val_loss: 1.1412
# Epoch 13/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 389s 2s/step - accuracy: 0.6708 - loss: 1.1346 - val_accuracy: 0.6581 - val_loss: 1.1394
# Epoch 14/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 396s 2s/step - accuracy: 0.6708 - loss: 1.1365 - val_accuracy: 0.6581 - val_loss: 1.1419
# Epoch 15/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 389s 2s/step - accuracy: 0.6708 - loss: 1.1352 - val_accuracy: 0.6581 - val_loss: 1.1412
# Epoch 16/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 386s 2s/step - accuracy: 0.6708 - loss: 1.1358 - val_accuracy: 0.6581 - val_loss: 1.1413
# Epoch 17/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 384s 2s/step - accuracy: 0.6708 - loss: 1.1346 - val_accuracy: 0.6581 - val_loss: 1.1416

# %%
pd.DataFrame(history1.history).plot()
# Out:
# <Axes: >

# %%
plt.plot(history1.history['val_loss'],label='validation loss')
plt.plot(history1.history['loss'],label='training loss')
plt.legend()
plt.show()

# %%
y_pred1 = model1.predict(test_gen)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step

# %%
pred_classes1 = y_pred1.argmax(axis=1)
pred_classes1 = pred_classes1[:test_gen.samples] ## get the first 1992 out of 13944 data so that the shape for confusion matrix is the same

# %%
ConfusionMatrixDisplay.from_predictions(test_gen.classes,pred_classes1)
plt.show()

# %%
mobilenet_model = MobileNetV2(
    weights = 'imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

mobilenet_model.trainable=False

# %%
model2 = Sequential([
    mobilenet_model,
    GlobalAveragePooling2D(),
    Dense(512,activation='relu'),
    Dropout(0.2),
    Dense(512,activation='relu'),
    Dropout(0.2),
    Dense(units=7,activation='softmax')
])

model2.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │         655,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,180,103 (12.13 MB)
#  Trainable params: 922,119 (3.52 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
model2.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
history2 = model2.fit(
    train_gen,
    validation_data=test_gen,
    epochs=20,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 267s 1s/step - accuracy: 0.6895 - loss: 0.9263 - val_accuracy: 0.7118 - val_loss: 0.8064
# Epoch 2/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 241s 970ms/step - accuracy: 0.7122 - loss: 0.8102 - val_accuracy: 0.7294 - val_loss: 0.8048
# Epoch 3/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 223s 898ms/step - accuracy: 0.7241 - loss: 0.7763 - val_accuracy: 0.7354 - val_loss: 0.7617
# Epoch 4/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 226s 910ms/step - accuracy: 0.7338 - loss: 0.7495 - val_accuracy: 0.7269 - val_loss: 0.7714
# Epoch 5/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 233s 940ms/step - accuracy: 0.7372 - loss: 0.7413 - val_accuracy: 0.7209 - val_loss: 0.7866
# Epoch 6/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 227s 913ms/step - accuracy: 0.7407 - loss: 0.7364 - val_accuracy: 0.7385 - val_loss: 0.7376
# Epoch 7/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 224s 904ms/step - accuracy: 0.7421 - loss: 0.7185 - val_accuracy: 0.7239 - val_loss: 0.7608
# Epoch 8/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 231s 932ms/step - accuracy: 0.7498 - loss: 0.7048 - val_accuracy: 0.7244 - val_loss: 0.7626
# Epoch 9/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 229s 925ms/step - accuracy: 0.7491 - loss: 0.6938 - val_accuracy: 0.7510 - val_loss: 0.7260
# Epoch 10/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 231s 933ms/step - accuracy: 0.7590 - loss: 0.6825 - val_accuracy: 0.7309 - val_loss: 0.7440
# Epoch 11/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 227s 916ms/step - accuracy: 0.7629 - loss: 0.6729 - val_accuracy: 0.7159 - val_loss: 0.7870
# Epoch 12/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 229s 925ms/step - accuracy: 0.7531 - loss: 0.6779 - val_accuracy: 0.7495 - val_loss: 0.7206
# Epoch 13/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 246s 991ms/step - accuracy: 0.7629 - loss: 0.6600 - val_accuracy: 0.7535 - val_loss: 0.6957
# Epoch 14/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 213s 860ms/step - accuracy: 0.7649 - loss: 0.6559 - val_accuracy: 0.7259 - val_loss: 0.7568
# Epoch 15/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 192s 776ms/step - accuracy: 0.7657 - loss: 0.6434 - val_accuracy: 0.7460 - val_loss: 0.7119
# Epoch 16/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 190s 764ms/step - accuracy: 0.7633 - loss: 0.6471 - val_accuracy: 0.7480 - val_loss: 0.7376
# Epoch 17/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 187s 754ms/step - accuracy: 0.7720 - loss: 0.6391 - val_accuracy: 0.7490 - val_loss: 0.7108
# Epoch 18/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 186s 751ms/step - accuracy: 0.7702 - loss: 0.6366 - val_accuracy: 0.7465 - val_loss: 0.7012
# Epoch 19/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 197s 795ms/step - accuracy: 0.7706 - loss: 0.6256 - val_accuracy: 0.7334 - val_loss: 0.7388
# Epoch 20/20
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.7765 - loss: 0.6182 - val_accuracy: 0.7339 - val_loss: 0.7203

# %%
pd.DataFrame(history2.history).plot()
# Out:
# <Axes: >

# %%
plt.plot(history2.history['val_loss'],label='validation loss')
plt.plot(history2.history['loss'],label='training loss')
plt.legend()
plt.show()

# %%
y_pred2 = model2.predict(test_gen)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 33s 477ms/step

# %%
pred_classes2 = y_pred2.argmax(axis=1)
pred_classes2 = pred_classes2[:test_gen.samples] ## get the first 1992 out of 13944 data so that the shape for confusion matrix is the same2

# %%
class_names = list(test_gen.class_indices.keys())

# %%
ConfusionMatrixDisplay.from_predictions(test_gen.classes,pred_classes2, display_labels=class_names, xticks_rotation=45)
plt.show()

# %%
sample_images = [f for f in os.listdir(SAMPLE_DIR) if f.endswith(('.jpg', '.jpeg', '.png', '.webp'))]

fig, axes = plt.subplots(2,4,figsize=(16,8))
axes = axes.flatten()

for i, img_name in enumerate(sample_images[:8]): 
    print(img_name)
    img_path = os.path.join(SAMPLE_DIR, img_name)
    img = image.load_img(img_path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = img_array/255.0

    pred = model2.predict(img_array, verbose=0)[0]
    pred_class_idx = np.argmax(pred)
    confidence = pred[pred_class_idx] * 100
    pred_label = class_names[pred_class_idx]
    # print(pred)

    axes[i].imshow(img)
    axes[i].set_title(f'{pred_label}\n({confidence:.1f}%)confident')
    axes[i].axis('off')
plt.suptitle('Model Prediction on sample images')
plt.tight_layout()
plt.show()
# Out:
# ISIC_0029325.jpg
# ISIC_0029334.jpg
# ISIC_0029341.jpg
# ISIC_0029371.jpg
# ISIC_0029377.jpg
# ISIC_0029382.jpg
# ISIC_0029386.jpg
# ISIC_0029396.jpg

# %%
t_lost,t_acc = model2.evaluate(test_gen, verbose=1)
t_acc
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 28s 436ms/step - accuracy: 0.7535 - loss: 0.6957
# 0.7535140514373779

# %%
model2.save('./skin_cancer.keras')
