# %%
! pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.13-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: packaging in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from requests->kagglehub) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from requests->kagglehub) (2025.11.12)
# Requirement already satisfied: colorama in c:\users\chin jia li\anaconda3\envs\tensorflow_env\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Downloading kagglehub-0.3.13-py3-none-any.whl (68 kB)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.13

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kmader/skin-cancer-mnist-ham10000")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/kmader/skin-cancer-mnist-ham10000?dataset_version_number=2...
# 100%|█████████████████████████████████████████████████████████████████████████████| 5.20G/5.20G [41:11<00:00, 2.26MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Chin Jia Li\.cache\kagglehub\datasets\kmader\skin-cancer-mnist-ham10000\versions\2
